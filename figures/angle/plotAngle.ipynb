# %%
import os
import sys
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_palette('deep')

SMALL_SIZE, MEDIUM_SIZE, LARGE_SIZE, TITLE_SIZE = 8, 10, 12, 14
plt.rc('font', size=LARGE_SIZE)  # controls default text sizes
plt.rc('axes', titlesize=TITLE_SIZE)  # fontsize of the axes title
plt.rc('axes', labelsize=LARGE_SIZE)  # fontsize of the x and y labels
plt.rc('xtick', labelsize=LARGE_SIZE)  # fontsize of the tick labels
plt.rc('ytick', labelsize=LARGE_SIZE)  # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)  # legend fontsize
plt.rc('legend', title_fontsize=MEDIUM_SIZE)  # legend fontsize
plt.rc('figure', titlesize=TITLE_SIZE)  # fontsize of the figure title

# %%
npNames = ('ordered', 'disordered')
fig, ax = plt.subplots(figsize=(5, 2.2))
legends = []
for npName in npNames:
    dfAll = pd.read_csv(f"{npName}_od_G3.csv", header=1)
    df = dfAll[dfAll["      Type1"] == "      Total"]
    print(df["        Avg"][0], df["    Std Dev"][0])
    legends.append(npName)
    df.drop(["      Type1", "      Type2", "      Type3", "        Avg", "    Std Dev", "        Max", "        Min", "   N Angles"], axis=1, inplace=True)
    df = df.convert_dtypes()
    df.set_index("      Frame", inplace=True)
    df.columns = df.columns.astype(float)
    df = df.transpose()
    df.plot(kind="line", ax=ax, legend=False)
plt.xlim(40, 180)
plt.xlabel(r'Bond angle ($\degree$)')
plt.ylabel("Fraction of atoms")
plt.legend(legends, loc='lower center', title=None, bbox_to_anchor=(0.83, 0.66), ncol=1, frameon=True)
plt.grid(linestyle='dotted')
plt.savefig('bAnglesOrderVsDisorder.png', bbox_inches='tight')
# Out:
# 96.0 35.4
# 94.9 34.1

# %%
print(sns.color_palette('deep').as_hex())
# Out:
# ['#4c72b0', '#dd8452', '#55a868', '#c44e52', '#8172b3', '#937860', '#da8bc3', '#8c8c8c', '#ccb974', '#64b5cd']
